# %%
import pandas as pd

# %%
pirLirUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002554243&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A7%80%EC%97%AD%EB%B3%84%20PIR%20%EB%B0%8F%20LIR_20211231"

# %%
try:
  pirLirDf = pd.read_csv(pirLirUrl, encoding = "ms949")
except Exception as e:
  pirLirDf = pd.read_csv(pirLirUrl, encoding = "utf-8")

# %%
pirLirDf.tail(2)
# Out:
#        연도   월  전국소득대비 주택가격 비율  서울소득대비 주택가격 비율  부산소득대비 주택가격 비율  대구소득대비 주택가격 비율  \
# 211  2021  10            6.69            8.55            6.91            7.67
# 212  2021  11            7.10            0.00           10.75           15.29
#
#      인천소득대비 주택가격 비율  광주소득대비 주택가격 비율  대전소득대비 주택가격 비율  울산소득대비 주택가격 비율  ...  \
# 211            8.92            7.17            6.72            6.65  ...
# 212           12.03            7.47            7.11            7.42  ...
#
#      세종 평균 연소득 대비 평균 대출금액  경기 평균 연소득 대비 평균 대출금액  강원 평균 연소득 대비 평균 대출금액  \
# 211                  4.85                  4.53                  2.98
# 212                  0.00                  4.36                  2.28
#
#      충북 평균 연소득 대비 평균 대출금액  충남 평균 연소득 대비 평균 대출금액  전북 평균 연소득 대비 평균 대출금액  \
# 211                  2.58                  2.99                  2.71
# 212                  1.71                  3.89                  1.89
#
#      전남평균 연소득 대비 평균 대출금액  경북 평균 연소득 대비 평균 대출금액  경남 평균 연소득 대비 평균 대출금액  \
# ...

# %%
import pandas as pd

# %%
zipCodeUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002336443&fileDetailSn=1&dataNm=%ED%86%B5%EA%B3%84%EC%B2%AD_%EB%82%98%EB%9D%BC%ED%86%B5%EA%B3%84_%EC%9A%B0%ED%8E%B8%EB%B2%88%ED%98%B8_20211110"

# %%
try:
  zipCodeDf = pd.read_csv(zipCodeUrl, encoding = "ms949")
except Exception as e:
  zipCodeDf = pd.read_csv(zipCodeUrl, encoding = "utf-8")

# %%
zipCodeDf.tail(2)
# Out:
#          우편번호  우편번호순서   도이름 시군구이름 읍면동이름 리건물이름   동호              전체주소
# 52541  799822       1  경상북도   울릉군    북면  나리2리  NaN  경상북도 울릉군 북면 나리2리
# 52542  799823       1  경상북도   울릉군    북면   현포리  NaN   경상북도 울릉군 북면 현포리
